# %% [markdown]
# # <span style="color:darkblue"> Lecture 5b - APIs and JSON </span>
#
# <font size = "5">
#
# In this lecture we will cover the basics of dictionaries and <br>
# interacting with web-based APIs

# %% [markdown]
# <font size = "5">
#
# Import packages

# %%
import requests      # Requests data from an API
import json          # Handles JSON object
import jmespath      # Allows you to mor easily navigate JSON objects
import pandas as pd  # Handles data frames

# %% [markdown]
# # <span style="color:darkblue"> I. Best Coding Practices </span>

# %% [markdown]
# <font size = "5">
#
# Splitting a command into multiple lines
#
# <font size = "3">
#
# - Sometimes strings are very long, e.g. URLs
# - Best practice to code lines with maximum 80 characters
# - It is easier to read code if you scroll vertically <br>
# rather than sideways

# %%
# You can split commands into multiple lines with a backlash
example_backslash = "This is a very long string" \
                    + "and I would like to break it down into multiple lines"

# You can also split commands into multiple lines by wrapping them in parentheses)
example_parenthesis = ( "This is a very long string" 
                    + "and I would like to break it down into multiple lines")

# %% [markdown]
# <font size = "5">
#
# Examples of Dictionary Formatting

# %%
# Define dictionary
dictionary_student = \
{
    "first_name": "John",
    "last_name" : "Smith",
    "location"  : "Atlanta",
    "university": "Emory",
}

# %% [markdown]
# <font size = "5">
# Nested dictionaries + Lists

# %%
dictionary_student_wgrades = \
{
    "first_name": "John",
    "last_name" : "Smith",
    "location"  : "Atlanta",
    "university": "Emory",
    "grades":{
        "computing":"A",
        "reasoning":"B",
        "applied":"A-"
    }
}

dictionary_liststudents = \
[{
    "first_name": "Ned",
    "last_name" : "Stark",
    "location"  : "Atlanta",
    "university": "Emory",
    
 },
 {
    "first_name": "Cersei",
    "last_name" : "Lannister",
    "location"  : "Decatur",
    "university": "Georgia Tech",
 }
]

# %% [markdown]
# <font size = "5">
#
# Convert dictionaries to JSON

# %%
# Convert dictionary to JSON
## json.dumps() converts the dictionary to a string
## json.loads() converts this string to a JSON object

json_student         = json.loads(json.dumps(dictionary_student ))
json_student_wgrades = json.loads(json.dumps(dictionary_student_wgrades))
json_liststudents    = json.loads(json.dumps(dictionary_liststudents))

# %% [markdown]
# <font size = "5">
#
# Navigating a JSON file by name

# %%
# The search command tries to search down the hierarchy, first "grades", then
# computing. The "." is used to separate the queries at different levels.

extract_info1 = jmespath.search('grades.computing', json_student_wgrades)
print(extract_info1)
# Out:
# A

# %% [markdown]
# <font size = "5">
#
# Navigating a JSON list by position

# %%
extract_info2 = jmespath.search('[0]', json_liststudents)
print(extract_info2)

extract_info3 = jmespath.search('[0].first_name', json_liststudents)
print(extract_info3)
# Out:
# {'first_name': 'Ned', 'last_name': 'Stark', 'location': 'Atlanta', 'university': 'Emory'}
# Ned

# %% [markdown]
# <font size = "5">
#
# Extracting elements at all sublevels

# %%
# This commands extracts the value of "first_name" for all students
# The [*] command 

extract_info3 = jmespath.search('[*].first_name', json_liststudents)
print(extract_info3)
# Out:
# ['Ned', 'Cersei']

# %% [markdown]
# # <span style="color:darkblue"> II. Accessing an API </span>

# %% [markdown]
# <font size = "5">
#
# About the example
#
# - OpenAlex is one of largest open access repositories <br>
# of bibliographic information
# - Contains millions of references and metada on <br>
# books, papers, authors, and citation networks
#
# https://docs.openalex.org

# %% [markdown]
# <font size = "5">
#
# Define an URL to access API
#
# ``` https://website.com/option=12345```
#
# - Usually it's a domain followed by a field
# - Many search engines use this type of format <br>
# for search queries

# %%
# Define a new string variable called "url_openalex_api"
# Notice that we used the backslash to splot the command, since
# the URL is quite long.

# In this case where are searching for all the works published 
# by an author whose ID is "A5023888391"

url_openalex_api = \
      "https://api.openalex.org/works?filter=author.id:A5023888391"

# %% [markdown]
# <font size = "5">
#
# Request data

# %%
# Obtain the JSON data of records from the open alex API
# Note: you can break the link using backslash

search_results = requests.\
    get(url_openalex_api).json()

# %% [markdown]
# <font size = "5">
#
# Convert to a JSON file for easier readability

# %%
# This commands opens the file to write it.
# The code in parenthesis of file.write(...) 
#     nicely formats the json file, with four character indentation.

with open('json_files/convert_search_results.json', 'w') as file: 
    file.write(json.dumps(search_results, indent =4))

# %% [markdown]
# <font size = "5">
#
# Browsing with the JSON data viewer
#
# <font size = "3">
#
# - Open the ```convert_search_results.json``` file from the folder in VSCode
# - Click on VS-Code's "View" tab at the top and click on the <br>
#  option "Command Palette". This will open a pop-up window. <br>
# <br>
#
# <img src="figures/command_palette.png" alt="drawing" width="150"/>
# <img src="figures/open_jsonviewer.png" alt="drawing" width="350"/>
#
# <br>
#
# - Install JSON viewer extension for VS-Code
# - Search "Open in JSON viewer" and click enter. This <br>
# should open a new tab with the following layout, which has <br>
# convenient drop-down menus: <br>
# <br>
#
# <img src="figures/json_viewer.png" alt="drawing" width="400"/>

# %% [markdown]
# <font size = "5">
#
# Try it yourself! Experiment with the JSON data viewer. <br>
# Diagnose how the data is structured and the different levels.

# %% [markdown]
# # <span style="color:darkblue"> III. Navigating the nested structure </span>

# %% [markdown]
# <font size = "5">
#
# Browse keys in the "first level"

# %%
# The "len" command is used to 
print(len(search_results))

# The "keys" subfunction extract the names of the "first-level" objects
print(search_results.keys())

# Store keys to data fram to easy access and visualization
search_results_keys = pd.DataFrame(search_results.keys())
# Out:
# 3
# dict_keys(['meta', 'results', 'group_by'])

# %% [markdown]
# <font size = "5">
#
# Browse subdictionary within a particular key

# %%
search_results["meta"]
# Out:
# {'count': 62,
#  'db_response_time_ms': 57,
#  'page': 1,
#  'per_page': 25,
#  'groups_count': None}

# %% [markdown]
# <font size = "5">
#
# Convert dictionary to pandas

# %%
# This code converts to Pandas

data = pd.DataFrame(search_results["meta"],index = [0])

data
# Out:
#    count  db_response_time_ms  page  per_page groups_count
# 0     62                   57     1        25         None

# %% [markdown]
# <font size = "5">
#
# Count elements at a particular level

# %%
# Count number of elements in list
len(search_results["results"])
# Out:
# 25

# %% [markdown]
# <font size = "5">
#
# You can access different sub elements

# %%
print(search_results["results"][0])
print(search_results["results"][1])

search_results["results"][0].keys()
# Out:
# {'id': 'https://openalex.org/W2741809807', 'doi': 'https://doi.org/10.7717/peerj.4375', 'title': 'The state of OA: a large-scale analysis of the prevalence and impact of Open Access articles', 'display_name': 'The state of OA: a large-scale analysis of the prevalence and impact of Open Access articles', 'publication_year': 2018, 'publication_date': '2018-02-13', 'ids': {'openalex': 'https://openalex.org/W2741809807', 'doi': 'https://doi.org/10.7717/peerj.4375', 'mag': '2741809807', 'pmid': 'https://pubmed.ncbi.nlm.nih.gov/29456894', 'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5815332'}, 'language': 'en', 'primary_location': {'is_oa': True, 'landing_page_url': 'https://doi.org/10.7717/peerj.4375', 'pdf_url': 'https://peerj.com/articles/4375.pdf', 'source': {'id': 'https://openalex.org/S1983995261', 'display_name': 'PeerJ', 'issn_l': '2167-8359', 'issn': ['2167-8359'], 'is_oa': True, 'is_in_doaj': True, 'is_core': True, 'host_organization': 'https://openalex.org/P4310320104', 'host_organization_name': 'PeerJ, Inc.', 'host_organization_lineage': ['https://openalex.org/P4310320104'], 'host_organization_lineage_names': ['PeerJ, Inc.'], 'type': 'journal'}, 'license': 'cc-by', 'license_id': 'https://openalex.org/licenses/cc-by', 'version': 'publishedVersion', 'is_accepted': True, 'is_published': True}, 'type': 'article', 'type_crossref': 'journal-article', 'indexed_in': ['crossref', 'doaj', 'pubmed'], 'open_access': {'is_oa': True, 'oa_status': 'gold', 'oa_url': 'https://peerj.com/articles/4375.pdf', 'any_repository_has_fulltext': True}, 'authorships': [{'author_position': 'first', 'author': {'id': 'https://openalex.org/A5048491430', 'display_name': 'Heather Piwowar', 'orcid': 'https://orcid.org/0000-0003-1613-5981'}, 'institutions': [{'id': 'https://openalex.org/I4210166736', 'display_name': 'Impact Technology Development (United States)', 'ror': 'https://ror.org/05ppvf150', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I4210166736']}], 'countries': ['US'], 'is_corresponding': False, 'raw_author_name': 'Heather Piwowar', 'raw_affiliation_strings': ['Impactstory, Sanford, NC, USA'], 'affiliations': [{'raw_affiliation_string': 'Impactstory, Sanford, NC, USA', 'institution_ids': ['https://openalex.org/I4210166736']}]}, {'author_position': 'middle', 'author': {'id': 'https://openalex.org/A5023888391', 'display_name': 'Jason Priem', 'orcid': 'https://orcid.org/0000-0001-6187-6610'}, 'institutions': [{'id': 'https://openalex.org/I4210166736', 'display_name': 'Impact Technology Development (United States)', 'ror': 'https://ror.org/05ppvf150', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I4210166736']}], 'countries': ['US'], 'is_corresponding': False, 'raw_author_name': 'Jason Priem', 'raw_affiliation_strings': ['Impactstory, Sanford, NC, USA'], 'affiliations': [{'raw_affiliation_string': 'Impactstory, Sanford, NC, USA', 'institution_ids': ['https://openalex.org/I4210166736']}]}, {'author_position': 'middle', 'author': {'id': 'https://openalex.org/A5068542997', 'display_name': 'Vincent Larivière', 'orcid': 'https://orcid.org/0000-0002-2733-0689'}, 'institutions': [{'id': 'https://openalex.org/I70931966', 'display_name': 'Université de Montréal', 'ror': 'https://ror.org/0161xgx34', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I70931966']}, {'id': 'https://openalex.org/I159129438', 'display_name': 'Université du Québec à Montréal', 'ror': 'https://ror.org/002rjbv21', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I159129438', 'https://openalex.org/I49663120']}], 'countries': ['CA'], 'is_corresponding': False, 'raw_author_name': 'Vincent Larivière', 'raw_affiliation_strings': ['Observatoire des Sciences et des Technologies (OST), Centre Interuniversitaire de Recherche sur la Science et la Technologie (CIRST), Université du Québec à Montréal, Montréal, QC, Canada', 'École de bibliothéconomie et des sciences de l’infor ...
# {'id': 'https://openalex.org/W2122130843', 'doi': 'https://doi.org/10.5210/fm.v15i7.2874', 'title': 'Scientometrics 2.0: New metrics of scholarly impact on the social Web', 'display_name': 'Scientometrics 2.0: New metrics of scholarly impact on the social Web', 'publication_year': 2010, 'publication_date': '2010-07-02', 'ids': {'openalex': 'https://openalex.org/W2122130843', 'doi': 'https://doi.org/10.5210/fm.v15i7.2874', 'mag': '2122130843'}, 'language': 'en', 'primary_location': {'is_oa': False, 'landing_page_url': 'https://doi.org/10.5210/fm.v15i7.2874', 'pdf_url': None, 'source': {'id': 'https://openalex.org/S102129144', 'display_name': 'First Monday', 'issn_l': '1396-0458', 'issn': ['1396-0458', '1396-0466'], 'is_oa': False, 'is_in_doaj': False, 'is_core': True, 'host_organization': 'https://openalex.org/P4310316040', 'host_organization_name': 'University of Illinois at Chicago', 'host_organization_lineage': ['https://openalex.org/P4310316040'], 'host_organization_lineage_names': ['University of Illinois at Chicago'], 'type': 'journal'}, 'license': None, 'license_id': None, 'version': None, 'is_accepted': False, 'is_published': False}, 'type': 'article', 'type_crossref': 'journal-article', 'indexed_in': ['crossref'], 'open_access': {'is_oa': False, 'oa_status': 'closed', 'oa_url': None, 'any_repository_has_fulltext': False}, 'authorships': [{'author_position': 'first', 'author': {'id': 'https://openalex.org/A5023888391', 'display_name': 'Jason Priem', 'orcid': 'https://orcid.org/0000-0001-6187-6610'}, 'institutions': [{'id': 'https://openalex.org/I114027177', 'display_name': 'University of North Carolina at Chapel Hill', 'ror': 'https://ror.org/0130frc33', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I114027177']}], 'countries': ['US'], 'is_corresponding': False, 'raw_author_name': 'Jason Priem', 'raw_affiliation_strings': ['School of Information and Library Science, University of North Carolina at Chapel Hill'], 'affiliations': [{'raw_affiliation_string': 'School of Information and Library Science, University of North Carolina at Chapel Hill', 'institution_ids': ['https://openalex.org/I114027177']}]}, {'author_position': 'last', 'author': {'id': 'https://openalex.org/A5001395463', 'display_name': 'Bradely H. Hemminger', 'orcid': None}, 'institutions': [{'id': 'https://openalex.org/I114027177', 'display_name': 'University of North Carolina at Chapel Hill', 'ror': 'https://ror.org/0130frc33', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I114027177']}], 'countries': ['US'], 'is_corresponding': False, 'raw_author_name': 'Bradely H. Hemminger', 'raw_affiliation_strings': ['School of Information and Library Science, University of North Carolina at Chapel Hill'], 'affiliations': [{'raw_affiliation_string': 'School of Information and Library Science, University of North Carolina at Chapel Hill', 'institution_ids': ['https://openalex.org/I114027177']}]}], 'institution_assertions': [], 'countries_distinct_count': 1, 'institutions_distinct_count': 1, 'corresponding_author_ids': [], 'corresponding_institution_ids': [], 'apc_list': None, 'apc_paid': None, 'fwci': 10.048, 'has_fulltext': False, 'cited_by_count': 374, 'citation_normalized_percentile': {'value': 0.999842, 'is_in_top_1_percent': True, 'is_in_top_10_percent': True}, 'cited_by_percentile_year': {'min': 99, 'max': 100}, 'biblio': {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}, 'is_retracted': False, 'is_paratext': False, 'primary_topic': {'id': 'https://openalex.org/T10064', 'display_name': 'Statistical Mechanics of Complex Networks', 'score': 0.945, 'subfield': {'id': 'https://openalex.org/subfields/3109', 'display_name': 'Statistical and Nonlinear Physics'}, 'field': {'id': 'https://openalex.org/fields/31', 'display_name': 'Physics and Astronomy'}, 'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}}, 'topics': [{'id': 'https://openalex.org/T10064',  ...
# dict_keys(['id', 'doi', 'title', 'display_name', 'publication_year', 'publication_date', 'ids', 'language', 'primary_location', 'type', 'type_crossref', 'indexed_in', 'open_access', 'authorships', 'institution_assertions', 'countries_distinct_count', 'institutions_distinct_count', 'corresponding_author_ids', 'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci', 'has_fulltext', 'fulltext_origin', 'cited_by_count', 'citation_normalized_percentile', 'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext', 'primary_topic', 'topics', 'keywords', 'concepts', 'mesh', 'locations_count', 'locations', 'best_oa_location', 'sustainable_development_goals', 'grants', 'datasets', 'versions', 'referenced_works_count', 'referenced_works', 'related_works', 'abstract_inverted_index', 'cited_by_api_url', 'counts_by_year', 'updated_date', 'created_date'])

# %% [markdown]
# <font size ="5">
#
# Gradually work through the nested structure!

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# <font size = "3">
#
# - Navigate the "results" file using the JSON Data Viewer
# - Use the "jmes.search()" to extract the "title" of all the <br>
# search results.

# %%
# Write your own code
extract_title = jmespath.search('results[*].title', search_results)
print(extract_title)
# Out:
# ['The state of OA: a large-scale analysis of the prevalence and impact of Open Access articles', 'Scientometrics 2.0: New metrics of scholarly impact on the social Web', 'Altmetrics in the wild: Using social media to explore scholarly impact', 'altmetrics: a manifesto', 'The Altmetrics Collection', 'How and why scholars cite on Twitter', 'Coverage and adoption of altmetrics sources in the bibliometric community', 'OpenAlex: A fully-open index of scholarly works, authors, venues, institutions, and concepts', 'Beyond the paper', "Beyond citations: Scholars' visibility on the social Web", 'The State of OA: A large-scale analysis of the prevalence and impact of Open Access articles', 'The Future of OA: A large-scale analysis projecting Open Access publication and readership', 'Data for free: Using LMS activity logs to measure community in online courses', 'The power of altmetrics on a CV', 'Decoupling the scholarly journal', 'The State of OA: A large-scale analysis of the prevalence and impact of Open Access articles', 'Introducing the Leiden Ranking Open Edition', 'Riding the crest of the altmetrics wave: How librarians can help prepare faculty for the next generation of research impact metrics', 'Riding the crest of the altmetrics wave: How librarians can help prepare faculty for the next generation of research impact metrics', 'CiteAs: Better Software through Sociotechnical Change for Better Software Citation', 'Prevalence and use of Twitter among scholars', 'Altmetrics (Chapter from Beyond Bibliometrics: Harnessing Multidimensional Indicators of Scholarly Impact)', 'As scholars undertake a great migration to online publishing, altmetrics stands to provide an academic measurement of twitter and other online activity', 'The Imperative for Open Altmetrics', 'Information visualization state of the art and future directions']

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# <font size = "3">
#
# - Convert ```search_results["results"]``` to a Pandas dataframe
# - Are there any columns with conversion issues?
#
# Note: Pandas conversion can into issues for variables, with <br>
# several levels of nesting and more data cleaning may be required <br>
# to properly code these cases.

# %%
# Write your own code
data1 = pd.DataFrame(search_results["results"])
data1
# Out:
#                                   id  \
# 0   https://openalex.org/W2741809807
# 1   https://openalex.org/W2122130843
# 2   https://openalex.org/W1553564559
# 3   https://openalex.org/W3130540911
# 4   https://openalex.org/W2396414759
# 5   https://openalex.org/W2041540760
# 6   https://openalex.org/W2038196424
# 7   https://openalex.org/W4229010617
# 8   https://openalex.org/W2059275568
# 9   https://openalex.org/W1519117689
# 10  https://openalex.org/W4245410681
# 11  https://openalex.org/W2980172586
# 12  https://openalex.org/W2104791248
# 13  https://openalex.org/W2051771537
# 14  https://openalex.org/W2144816075
# 15  https://openalex.org/W4235038322
# 16  https://openalex.org/W4391560706
# 17  https://openalex.org/W2109312864
# 18  https://openalex.org/W2949915600
# 19  https://openalex.org/W3208256308
# 20    https://openalex.org/W87230806
# 21   https://openalex.org/W854896339
# 22  https://openalex.org/W2290499851
# 23  https://openalex.org/W2017292130
# 24  https://openalex.org/W2143461694
#
#                                                doi  \
# 0               https://doi.org/10.7717/peerj.4375
# 1            https://doi.org/10.5210/fm.v15i7.2874
# 2         https://doi.org/10.48550/arxiv.1203.4745
# 3                                             None
# 4     https://doi.org/10.1371/journal.pone.0048753
# 5         https://doi.org/10.1002/meet.14504701201
# 6        https://doi.org/10.1007/s11192-013-1221-3
# 7        https://doi.org/10.48550/arxiv.2205.01833
# 8                  https://doi.org/10.1038/495437a
# 9         https://doi.org/10.48550/arxiv.1205.5611
# 10    https://doi.org/10.7287/peerj.preprints.3119
# 11                  https://doi.org/10.1101/795310
# 12    https://doi.org/10.1016/j.iheduc.2008.03.002
# 13    https://doi.org/10.1002/bult.2013.1720390405
# 14        https://doi.org/10.3389/fncom.2012.00019
# 15  https://doi.org/10.7287/peerj.preprints.3119v1
# 16            https://doi.org/10.59350/89wpz-hpz32
# 17          https://doi.org/10.5860/crln.74.6.8960
# 18                                            None
# 19         https://doi.org/10.1145/3462204.3482889
# 20   https://doi.org/10.6084/m9.figshare.104629.v1
# 21       https://doi.org/10.48550/arxiv.1507.01328
# 22                                            None
# 23        https://doi.org/10.3998/3336451.0017.301
# 24        https://doi.org/10.1002/meet.14504901155
#
#                                                 title  \
# 0   The state of OA: a large-scale analysis of the...
# 1   Scientometrics 2.0: New metrics of scholarly i...
# 2   Altmetrics in the wild: Using social media to ...
# 3                             altmetrics: a manifesto
# 4                           The Altmetrics Collection
# 5                How and why scholars cite on Twitter
# 6   Coverage and adoption of altmetrics sources in...
# 7   OpenAlex: A fully-open index of scholarly work...
# 8                                    Beyond the paper
# 9   Beyond citations: Scholars' visibility on the ...
# 10  The State of OA: A large-scale analysis of the...
# 11  The Future of OA: A large-scale analysis proje...
# 12  Data for free: Using LMS activity logs to meas...
# 13                    The power of altmetrics on a CV
# 14                   Decoupling the scholarly journal
# 15  The State of OA: A large-scale analysis of the...
# 16        Introducing the Leiden Ranking Open Edition
# 17  Riding the crest of the altmetrics wave: How l...
# 18  Riding the crest of the altmetrics wave: How l...
# 19  CiteAs: Better Software through Sociotechnical...
# 20       Prevalence and use of Twitter among scholars
# 21  Altmetrics (Chapter from Beyond Bibliometrics:...
# 22  As scholars undertake a great migration to onl...
# 23                 The Imperative for Open Altmetrics
# 24  Information visualization state of the art and...
#
#                                          display_name  publication_year  \
# 0   The state of OA: a large-scale analysis of the...              2018
# 1   Scientometrics 2.0: New metrics of scholarly i...              2010
# 2   Altmetrics in the wild: Using social media to ...              2012
# 3                             altmetrics: a manifesto              2011
# 4                           The Altmetrics Collection              2012
# 5                How and why scholars cite on Twitter              2010
# 6   Coverage and adoption of altmetrics sources in...              2014
# 7   OpenAlex: A fully-open index of scholarly work...              2022
# 8                                    Beyond the paper              2013
# 9   Beyond citations: Scholars' visibility on the ...              2012
# 10  The State of OA: A large-scale analysis of the...              2017
# 11  The Future of OA: A large-scale analysis proje...              2019
# 12  Data for free: Using LMS activity logs to meas...              2008
# 13                    The power of altmetrics on a CV              2013
# 14                   Decoupling the scholarly journal              2012
# 15  The State of OA: A large-scale analysis of the...              2017
# 16        Introducing the Leiden Ranking Open Edition              2024
# 17  Riding the crest of the altmetrics wave: How l...              2013
# 18  Riding the crest of the altmetrics wave: How l...              2013
# 19  CiteAs: Better Software through Sociotechnical...              2021
# 20       Prevalence and use of Twitter among scholars              2012
# 21  Altmetrics (Chapter from Beyond Bibliometrics:...              2015
# 22  As scholars undertake a great migration to onl...              2011
# 23                 The Imperative for Open Altmetrics              2014
# 24  Information visualization state of the art and...              2012
#
#    publication_date                                                ids  \
# 0        2018-02-13  {'openalex': 'https://openalex.org/W2741809807...
# 1        2010-07-02  {'openalex': 'https://openalex.org/W2122130843...
# 2        2012-01-01  {'openalex': 'https://openalex.org/W1553564559...
# 3        2011-01-01  {'openalex': 'https://openalex.org/W3130540911...
# 4        2012-11-01  {'openalex': 'https://openalex.org/W2396414759...
# 5        2010-11-01  {'openalex': 'https://openalex.org/W2041540760...
# 6        2014-01-04  {'openalex': 'https://openalex.org/W2038196424...
# 7        2022-01-01  {'openalex': 'https://openalex.org/W4229010617...
# 8        2013-03-01  {'openalex': 'https://openalex.org/W2059275568...
# 9        2012-01-01  {'openalex': 'https://openalex.org/W1519117689...
# 10       2017-08-02  {'openalex': 'https://openalex.org/W4245410681...
# 11       2019-10-09  {'openalex': 'https://openalex.org/W2980172586...
# 12       2008-01-01  {'openalex': 'https://openalex.org/W2104791248...
# 13       2013-04-01  {'openalex': 'https://openalex.org/W2051771537...
# 14       2012-01-01  {'openalex': 'https://openalex.org/W2144816075...
# 15       2017-08-02  {'openalex': 'https://openalex.org/W4235038322...
# 16       2024-01-30  {'openalex': 'https://openalex.org/W4391560706...
# 17       2013-06-01  {'openalex': 'https://openalex.org/W2109312864...
# 18       2013-05-15  {'openalex': 'https://openalex.org/W2949915600...
# 19       2021-10-23  {'openalex': 'https://openalex.org/W3208256308...
# 20       2012-12-16  {'openalex': 'https://openalex.org/W87230806',...
# 21       2015-01-01  {'openalex': 'https://openalex.org/W854896339'...
# 22       2011-11-21  {'openalex': 'https://openalex.org/W2290499851...
# 23       2014-09-22  {'openalex': 'https://openalex.org/W2017292130...
# 24       2012-01-01  {'openalex': 'https://openalex.org/W2143461694...
#
#    language                                   primary_location      type  ...  \
# 0        en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 1        en  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 2        en  {'is_oa': True, 'landing_page_url': 'https://a...  preprint  ...
# 3        ca  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 4        en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 5        en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 6        en  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 7        en  {'is_oa': True, 'landing_page_url': 'https://a...  preprint  ...
# 8        en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 9        en  {'is_oa': True, 'landing_page_url': 'https://a...  preprint  ...
# 10       en  {'is_oa': True, 'landing_page_url': 'https://d...  preprint  ...
# 11       en  {'is_oa': True, 'landing_page_url': 'https://d...  preprint  ...
# 12       en  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 13       en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 14       en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 15       en  {'is_oa': True, 'landing_page_url': 'https://d...  preprint  ...
# 16       en  {'is_oa': True, 'landing_page_url': 'https://d...  preprint  ...
# 17       en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 18       en                                               None  preprint  ...
# 19       en  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 20       en  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 21       en  {'is_oa': True, 'landing_page_url': 'https://a...  preprint  ...
# 22       en  {'is_oa': False, 'landing_page_url': 'https://...   article  ...
# 23       en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
# 24       en  {'is_oa': True, 'landing_page_url': 'https://d...   article  ...
#
#    datasets versions referenced_works_count  \
# 0        []       []                     45
# 1        []       []                      0
# 2        []       []                      0
# 3        []       []                      0
# 4        []       []                     28
# 5        []       []                     14
# 6        []       []                     38
# 7        []       []                      6
# 8        []       []                      9
# 9        []       []                     20
# 10       []       []                      0
# 11       []       []                      6
# 12       []       []                     54
# 13       []       []                      0
# 14       []       []                     56
# 15       []       []                      0
# 16       []       []                      0
# 17       []       []                      8
# 18       []       []                      6
# 19       []       []                     10
# 20       []       []                      0
# 21       []       []                     50
# 22       []       []                      0
# 23       []       []                     14
# 24       []       []                     13
#
#                                      referenced_works  \
# 0   [https://openalex.org/W1560783210, https://ope...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [https://openalex.org/W1559646899, https://ope...
# 5   [https://openalex.org/W1531586847, https://ope...
# 6   [https://openalex.org/W1519117689, https://ope...
# 7   [https://openalex.org/W1932742904, https://ope...
# 8   [https://openalex.org/W1572136682, https://ope...
# 9   [https://openalex.org/W1507867301, https://ope...
# 10                                                 []
# 11  [https://openalex.org/W2029057325, https://ope...
# 12  [https://openalex.org/W14494740, https://opena...
# 13                                                 []
# 14  [https://openalex.org/W10966293, https://opena...
# 15                                                 []
# 16                                                 []
# 17  [https://openalex.org/W1519117689, https://ope...
# 18  [https://openalex.org/W1553564559, https://ope...
# 19  [https://openalex.org/W1622429627, https://ope...
# 20                                                 []
# 21  [https://openalex.org/W1488712546, https://ope...
# 22                                                 []
# 23  [https://openalex.org/W1031369026, https://ope...
# 24  [https://openalex.org/W1568669012, https://ope...
#
#                                         related_works  \
# 0   [https://openalex.org/W3203790917, https://ope...
# 1   [https://openalex.org/W4385506752, https://ope...
# 2   [https://openalex.org/W3211611723, https://ope...
# 3   [https://openalex.org/W2963475133, https://ope...
# 4   [https://openalex.org/W3150373829, https://ope...
# 5   [https://openalex.org/W3182114520, https://ope...
# 6   [https://openalex.org/W4301494992, https://ope...
# 7   [https://openalex.org/W4385804830, https://ope...
# 8   [https://openalex.org/W2899084033, https://ope...
# 9   [https://openalex.org/W598185802, https://open...
# 10  [https://openalex.org/W4382048646, https://ope...
# 11  [https://openalex.org/W4388566120, https://ope...
# 12  [https://openalex.org/W3207368856, https://ope...
# 13  [https://openalex.org/W4384945517, https://ope...
# 14  [https://openalex.org/W3103825105, https://ope...
# 15  [https://openalex.org/W4382048646, https://ope...
# 16  [https://openalex.org/W2748952813, https://ope...
# 17  [https://openalex.org/W4377088579, https://ope...
# 18  [https://openalex.org/W853105216, https://open...
# 19  [https://openalex.org/W2822474803, https://ope...
# 20  [https://openalex.org/W3203401462, https://ope...
# 21  [https://openalex.org/W4385506752, https://ope...
# 22  [https://openalex.org/W3168199097, https://ope...
# 23  [https://openalex.org/W4242559205, https://ope...
# 24  [https://openalex.org/W2423964256, https://ope...
#
#                               abstract_inverted_index  \
# 0   {'Despite': [0], 'growing': [1], 'interest': [...
# 1   {'The': [0], 'growing': [1], 'flood': [2], 'of...
# 2   {'In': [0], 'growing': [1], 'numbers,': [2], '...
# 3                                                None
# 4   {'What': [0], 'paper': [1], 'should': [2, 7, 1...
# 5   {'Proceedings': [0, 2598, 2717, 2757, 2940], '...
# 6   {'Altmetrics,': [0], 'indices': [1, 20], 'base...
# 7   {'OpenAlex': [0], 'is': [1, 60, 79], 'a': [2, ...
# 8   {'The': [0], 'journal': [1], 'and': [2, 12], '...
# 9   {'Traditionally,': [0], 'scholarly': [1, 15], ...
# 10  {'Despite': [0], 'growing': [1], 'interest': [...
# 11  {'Summary': [0], 'Understanding': [1], 'the': ...
# 12  {'In': [0], 'the': [1, 47, 52, 58], 'study': [...
# 13  {'Abstract': [0], 'Editor's': [1], 'Summary': ...
# 14  {'Although': [0], 'many': [1], 'observers': [2...
# 15  {'Despite': [0], 'growing': [1], 'interest': [...
# 16  {'When': [0], 'the': [1, 7, 25, 28, 31, 36], '...
# 17  {'As': [0, 60], 'scholars': [1], 'migrate': [2...
# 18  {'As': [0, 60], 'scholars': [1], 'migrate': [2...
# 19  {'Research': [0], 'increasingly': [1], 'depend...
# 20                                               None
# 21  {'This': [0], 'chapter': [1], 'discusses': [2]...
# 22  {'The': [0], 'internet': [1], 'seems': [2], 't...
# 23  {'If': [0, 844], 'scholarly': [1, 125, 154, 25...
# 24  {'Abstract': [0], 'The': [1, 27], 'panel': [2,...
#
#                                      cited_by_api_url  \
# 0   https://api.openalex.org/works?filter=cites:W2...
# 1   https://api.openalex.org/works?filter=cites:W2...
# 2   https://api.openalex.org/works?filter=cites:W1...
# 3   https://api.openalex.org/works?filter=cites:W3...
# 4   https://api.openalex.org/works?filter=cites:W2...
# 5   https://api.openalex.org/works?filter=cites:W2...
# 6   https://api.openalex.org/works?filter=cites:W2...
# 7   https://api.openalex.org/works?filter=cites:W4...
# 8   https://api.openalex.org/works?filter=cites:W2...
# 9   https://api.openalex.org/works?filter=cites:W1...
# 10  https://api.openalex.org/works?filter=cites:W4...
# 11  https://api.openalex.org/works?filter=cites:W2...
# 12  https://api.openalex.org/works?filter=cites:W2...
# 13  https://api.openalex.org/works?filter=cites:W2...
# 14  https://api.openalex.org/works?filter=cites:W2...
# 15  https://api.openalex.org/works?filter=cites:W4...
# 16  https://api.openalex.org/works?filter=cites:W4...
# 17  https://api.openalex.org/works?filter=cites:W2...
# 18  https://api.openalex.org/works?filter=cites:W2...
# 19  https://api.openalex.org/works?filter=cites:W3...
# 20  https://api.openalex.org/works?filter=cites:W8...
# 21  https://api.openalex.org/works?filter=cites:W8...
# 22  https://api.openalex.org/works?filter=cites:W2...
# 23  https://api.openalex.org/works?filter=cites:W2...
# 24  https://api.openalex.org/works?filter=cites:W2...
#
#                                        counts_by_year  \
# 0   [{'year': 2024, 'cited_by_count': 83}, {'year'...
# 1   [{'year': 2024, 'cited_by_count': 8}, {'year':...
# 2   [{'year': 2023, 'cited_by_count': 7}, {'year':...
# 3   [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 4   [{'year': 2024, 'cited_by_count': 8}, {'year':...
# 5   [{'year': 2024, 'cited_by_count': 2}, {'year':...
# 6   [{'year': 2024, 'cited_by_count': 5}, {'year':...
# 7   [{'year': 2024, 'cited_by_count': 30}, {'year'...
# 8   [{'year': 2024, 'cited_by_count': 4}, {'year':...
# 9   [{'year': 2024, 'cited_by_count': 1}, {'year':...
# 10  [{'year': 2024, 'cited_by_count': 4}, {'year':...
# 11  [{'year': 2024, 'cited_by_count': 9}, {'year':...
# 12  [{'year': 2023, 'cited_by_count': 3}, {'year':...
# 13  [{'year': 2023, 'cited_by_count': 2}, {'year':...
# 14  [{'year': 2023, 'cited_by_count': 9}, {'year':...
# 15  [{'year': 2024, 'cited_by_count': 1}, {'year':...
# 16              [{'year': 2024, 'cited_by_count': 1}]
# 17  [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 18  [{'year': 2020, 'cited_by_count': 1}, {'year':...
# 19  [{'year': 2024, 'cited_by_count': 2}, {'year':...
# 20  [{'year': 2021, 'cited_by_count': 1}, {'year':...
# 21  [{'year': 2020, 'cited_by_count': 2}, {'year':...
# 22  [{'year': 2019, 'cited_by_count': 1}, {'year':...
# 23  [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 24  [{'year': 2020, 'cited_by_count': 1}, {'year':...
#
#                   updated_date created_date
# 0   2024-09-24T13:11:44.699787   2017-08-08
# 1   2024-09-25T07:08:00.769007   2016-06-24
# 2   2024-09-27T15:18:22.037319   2016-06-24
# 3   2024-09-26T03:03:28.396133   2021-03-01
# 4   2024-09-18T13:09:16.185631   2016-06-24
# 5   2024-09-24T04:34:03.379402   2016-06-24
# 6   2024-09-13T01:09:23.318928   2016-06-24
# 7   2024-09-26T12:36:02.205423   2022-05-08
# 8   2024-09-25T00:36:03.891290   2016-06-24
# 9   2024-09-19T23:08:29.970583   2016-06-24
# 10  2024-09-24T10:42:48.787782   2022-05-12
# 11  2024-09-18T04:12:56.029792   2019-10-18
# 12  2024-09-25T16:53:22.247848   2016-06-24
# 13  2024-09-26T21:33:53.247923   2016-06-24
# 14  2024-09-27T00:25:09.508827   2016-06-24
# 15  2024-09-23T21:18:32.879925   2022-05-12
# 16  2024-09-19T13:13:11.618196   2024-02-07
# 17  2024-09-14T15:13:42.404011   2016-06-24
# 18  2024-09-26T06:41:11.695094   2019-06-27
# 19  2024-09-15T10:05:37.876976   2021-11-08
# 20  2024-09-26T10:41:49.054021   2016-06-24
# 21  2024-09-19T19:13:55.798487   2016-06-24
# 22  2024-09-17T12:23:39.412768   2016-06-24
# 23  2024-09-26T07:30:54.456157   2016-06-24
# 24  2024-09-25T08:27:21.337560   2016-06-24
#
# [25 rows x 50 columns]

# %% [markdown]
# # <span style="color:darkblue"> IV. Hands-on Experience </span>

# %% [markdown]
# The Open Library also contains bibliographic information.
#
# You can search for sports books with the API link
#
# http://openlibrary.org/search.json?title=sports
#
# 1. Get information from this website using requests
# 2. Store the result in a JSON file and open it with data viewer.
# 2. Find out the main keys
# 3. How many search results are there?
# 4. What data can you obtain? Think carefully about <br>
# how to convert this into a workable pandas format

# %%
# Write your own code
url_sportsbooks_api = \
    'http://openlibrary.org/search.json?title=sports'

search_sportsbooks = requests.\
                     get(url_sportsbooks_api).json()

with open('json_files/convert_search_sportsbooks.json', 'w') as file: 
    file.write(json.dumps(search_sportsbooks, indent =4))

search_sportsbooks_keys = search_sportsbooks.keys()
print(search_sportsbooks_keys)
# Out:
# dict_keys(['numFound', 'start', 'numFoundExact', 'docs', 'num_found', 'q', 'offset'])

# %% [markdown]
# # <span style="color:darkblue"> V. Further Reading </span>

# %% [markdown]
# <font size = "5">
#
# Learn more about how to use advanced JSON queries with JMES at
#
# - This can be very useful to navigate the nested structure
# - Examples of syntax and advanced search terms
#
# https://jmespath.org/tutorial.html

# %% [markdown]
# <font size = "5">
#
# Learn more about JSON at <br>
#
# https://www.w3schools.com/js/js_json_intro.asp

# %% [markdown]
# <font size = "5">
#
# https://saturncloud.io/blog/how-to-convert-nested-json-to-pandas-dataframe-with-specific-format/

# %% [markdown]
# <font size = "5">
#
# Check the following textbook on our reading list, Chapter 7:
#
# https://www.amazon.com/Introduction-Programming-Business-Science-Applications/dp/1544377444

# %% [markdown]
# <font size = "5">
#
# There are several online resources for further practice at:
#
# https://study.sagepub.com/researchmethods/statistics/kaefer-intro-to-python
